# %% [markdown]
# # Submission 5: RNN Journey Model
#
# This submission trains a PyTorch GRU model on fixed-length event sequences from Charlie's K-cut journey snapshots, then scores the new `open_journeys2.csv` journeys in `open_journeys2_flattened_all0.csv` order.

# %% [markdown]
# ## Run Pipeline

# %%
# If needed on Kaggle/local:
# %pip install -q polars pyarrow torch scikit-learn

from pathlib import Path
import runpy

script_candidates = [
    Path.cwd() / 'submission5_rnn_pipeline.py',
    Path.cwd() / 'joel' / 'kaggle_sumissions' / 'submission5' / 'submission5_rnn_pipeline.py',
]
script_path = next(path for path in script_candidates if path.exists())
_ = runpy.run_path(script_path, run_name='__main__')
# Out:
# Submission dir: /Users/joelyoon/Documents/git_repo/m148-project/joel/kaggle_sumissions/submission5
# Max train snapshots: 120000
# Max sequence length: 80
# Device: mps
# Train/valid rows: 95980 24020
# epoch=1 loss=0.30471 valid_prauc=0.11710 valid_brier=0.04640
# epoch=2 loss=0.18334 valid_prauc=0.18407 valid_brier=0.04567
# epoch=3 loss=0.17866 valid_prauc=0.22309 valid_brier=0.04450
# epoch=4 loss=0.17285 valid_prauc=0.21045 valid_brier=0.04378
# Wrote: /Users/joelyoon/Documents/git_repo/m148-project/joel/kaggle_sumissions/submission5/submission.csv
# Rows: 123467
# Probability range: 4.070739e-21 0.56562537
