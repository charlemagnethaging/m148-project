# %% [markdown]
# # Submission 6: LSTM Journey Model
#
# This submission trains a PyTorch bidirectional LSTM model on fixed-length event sequences from Charlie's K-cut journey snapshots, then scores the new `open_journeys2.csv` journeys in `open_journeys2_flattened_all0.csv` order.

# %% [markdown]
# ## Run Pipeline

# %%
# If needed on Kaggle/local:
# %pip install -q polars pyarrow torch scikit-learn

from pathlib import Path
import runpy

script_candidates = [
    Path.cwd() / 'submission6_lstm_pipeline.py',
    Path.cwd() / 'joel' / 'kaggle_sumissions' / 'submission6' / 'submission6_lstm_pipeline.py',
]
script_path = next(path for path in script_candidates if path.exists())
_ = runpy.run_path(script_path, run_name='__main__')
# Out:
# Submission dir: /Users/joelyoon/Documents/git_repo/m148-project/joel/kaggle_sumissions/submission6
# Max train snapshots: 120000
# Max sequence length: 80
# Device: mps
# Train/valid rows: 95980 24020
# epoch=1 loss=0.31878 valid_prauc=0.08766 valid_brier=0.04682
# epoch=2 loss=0.18530 valid_prauc=0.18571 valid_brier=0.04559
# epoch=3 loss=0.17688 valid_prauc=0.21532 valid_brier=0.04394
# epoch=4 loss=0.17091 valid_prauc=0.21669 valid_brier=0.04342
# Wrote: /Users/joelyoon/Documents/git_repo/m148-project/joel/kaggle_sumissions/submission6/submission.csv
# Rows: 123467
# Probability range: 4.635344e-15 0.6227758
